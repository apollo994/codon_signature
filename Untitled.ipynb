# %%
import pandas as pd
import numpy as np

# %%
codon_count=pd.read_csv('o576245-Refseq_species.tsv', sep='\t')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
codon_count.head()
# Out:
#                Division  Assembly                                 Taxid  \
# refseq  GCF_002287175.1      2161             Methanobacterium bryantii
# refseq  GCF_000302455.1   1204725  Methanobacterium formicicum DSM 3637
# refseq  GCF_000762265.1      2162           Methanobacterium formicicum
# refseq  GCF_000953115.1      2162           Methanobacterium formicicum
# refseq  GCF_001458655.1      2162           Methanobacterium formicicum
#
#         Species  Organelle  Translation Table   # CDS  # Codons    GC%   GC1%  \
# refseq  genomic         11               3204  896715     35.51  45.62  34.02
# refseq  genomic         11               2476  706189     40.87  49.76  34.86
# refseq  genomic         11               2342  672334     43.71  51.56  35.31
# refseq  genomic         11               2363  684284     43.57  51.45  35.35
# refseq  genomic         11               2347  684586     43.51  51.35  35.20
#
# ...

# %%
codon_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152902 entries, refseq to refseq
# Data columns (total 76 columns):
# Division             144242 non-null object
# Assembly             152902 non-null int64
# Taxid                152902 non-null object
# Species              152902 non-null object
# Organelle            152902 non-null int64
# Translation Table    152902 non-null int64
# # CDS                152902 non-null int64
# # Codons             152902 non-null float64
# GC%                  152902 non-null float64
# GC1%                 152902 non-null float64
# GC2%                 152902 non-null float64
# GC3%                 152902 non-null int64
# TTT                  152902 non-null int64
# TTC                  152902 non-null int64
# TTA                  152902 non-null int64
# TTG                  152902 non-null int64
# CTT                  152902 non-null int64
# CTC                  152902 non-null int64
# CTA                  152902 non-null int64
# ...

# %%
# %Bash python get_codon_freq.py --input o576245-Refseq_species.tsv --id 2161
# Out:
# UsageError: Line magic function `%Bash` not found.
