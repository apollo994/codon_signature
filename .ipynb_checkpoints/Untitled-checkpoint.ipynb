# %%
import pandas as pd
import numpy as np

# %%
args_input='o576245-Refseq_species.tsv'
args_id=521

# %%
verbose=True

genecode=dict()
genecode["A"] = ["GCT","GCC","GCA","GCG"]
genecode["L"] = ["TTA","TTG","CTT","CTC","CTA","CTG"]
genecode["R"] = ["CGT","CGC","CGA","CGG","AGA","AGG"]
genecode["K"] = ["AAA","AAG"]
genecode["N"] = ["AAT","AAC"]
genecode["M"] = ["ATG"]
genecode["D"] = ["GAT","GAC"]
genecode["F"] = ["TTT","TTC"]
genecode["C"] = ["TGT","TGC"]
genecode["P"] = ["CCT","CCC","CCA","CCG"]
genecode["Q"] = ["CAA","CAG"]
genecode["S"] = ["TCT","TCC","TCA","TCG","AGT","AGC"]
genecode["E"] = ["GAA","GAG"]
genecode["T"] = ["ACT","ACC","ACA","ACG"]
genecode["G"] = ["GGT","GGC","GGA","GGG"]
genecode["W"] = ["TGG"]
genecode["H"] = ["CAT","CAC"]
genecode["Y"] = ["TAT","TAC"]
genecode["I"] = ["ATT","ATC","ATA"]
genecode["V"] = ["GTT","GTC","GTA","GTG"]
genecode["Z"] = ["TAA","TGA","TAG"]

# Ideaa Fabio: invece di fare un ciclo for, carica il file in un dataframe, prendi tutte i nomi delle colonne e elimina quelle che non interessano"
# Create a list of variable names to be kept
to_keep=["Species","Assembly"]
# Append to the 'to_keep' list the codon columns from the input table
# that corresponds to each aminoacid in the genecode dictionary
for AA in genecode:
    for trip in genecode[AA]:
        to_keep.append(trip)
if verbose==True:
    print("Line to to_keep\n",to_keep,"\n Done")
    
data=pd.read_csv(args_input, sep="\t", index_col=False, low_memory=False)
data=data.set_index("Taxid")
# Create a new dataframe RefSeq tax ID,Species,Assembly and all the codons from genecode dictionary as columns
# that is has only the rows where RefSeq is equal to the input Tax Id
one_id_data=(data.loc[args_id,to_keep])
if verbose==True:
    print("DataFrame columns\n",one_id_data,"\n Done")
# data.index.names = [None]
ratio_all=pd.DataFrame(index=data.index)
print(ratio_all)
#table with all triplets frequencies
for AA in genecode:
    sub_columns=[]#"Assembly"
    sub_columns.extend(genecode[AA])
    print(sub_columns,"\n Done")
    sub_data=data.loc[:,sub_columns]
    if verbose==True:
        print("Subset of codon columns for ",AA,":\n",sub_data, "\n Done")
    ratio_subdata=sub_data.div(sub_data.sum(axis=1), axis=0)
    if verbose==True:
        print("Relative frequency of codon usage for",AA,":\n", ratio_subdata,"\n Done")
    ratio_all=pd.concat([ratio_all,ratio_subdata])
#to do explicitely declares which columns has to be rounded
ratio_all=ratio_all.round(2)
print (ratio_all)
# Out:
# Line to to_keep
#  ['Species', 'Assembly', 'GCT', 'GCC', 'GCA', 'GCG', 'TTA', 'TTG', 'CTT', 'CTC', 'CTA', 'CTG', 'CGT', 'CGC', 'CGA', 'CGG', 'AGA', 'AGG', 'AAA', 'AAG', 'AAT', 'AAC', 'ATG', 'GAT', 'GAC', 'TTT', 'TTC', 'TGT', 'TGC', 'CCT', 'CCC', 'CCA', 'CCG', 'CAA', 'CAG', 'TCT', 'TCC', 'TCA', 'TCG', 'AGT', 'AGC', 'GAA', 'GAG', 'ACT', 'ACC', 'ACA', 'ACG', 'GGT', 'GGC', 'GGA', 'GGG', 'TGG', 'CAT', 'CAC', 'TAT', 'TAC', 'ATT', 'ATC', 'ATA', 'GTT', 'GTC', 'GTA', 'GTG', 'TAA', 'TGA', 'TAG']
# 1608101  0.021978  0.027473  0.049451  0.010989  0.554945  0.335165
#
# [152902 rows x 6 columns]
#  Done
# ['AAA', 'AAG']
#  Done
# Subset of codon columns for  K :
#             AAA    AAG
# Taxid
# 2161     57576  13439
# 1204725  36587  12476
# 2162     32289  13271
# 2162     33045  13427
# 2162     32897  13445
# ...        ...    ...
# 1923457     92     54
# 1923492    108     79
# 1922934    262     93
# 1922884    164    129
# 1608101    158    118
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for K :
#                AAA       AAG
# Taxid
# 2161     0.810758  0.189242
# 1204725  0.745715  0.254285
# 2162     0.708714  0.291286
# 2162     0.711073  0.288927
# 2162     0.709874  0.290126
# ...           ...       ...
# 1923457  0.630137  0.369863
# 1923492  0.577540  0.422460
# 1922934  0.738028  0.261972
# 1922884  0.559727  0.440273
# 1608101  0.572464  0.427536
#
# [152902 rows x 2 columns]
#  Done
# ['AAT', 'AAC']
#  Done
# Subset of codon columns for  N :
#             AAT    AAC
# Taxid
# 2161     34897  15558
# 1204725  19859  14605
# 2162     15981  15162
# 2162     16468  15339
# 2162     16696  15441
# ...        ...    ...
# 1923457     89     24
# 1923492    100     63
# 1922934    179     89
# 1922884    123     70
# 1608101    149     54
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for N :
#                AAT       AAC
# Taxid
# 2161     0.691646  0.308354
# 1204725  0.576224  0.423776
# 2162     0.513149  0.486851
# 2162     0.517748  0.482252
# 2162     0.519526  0.480474
# ...           ...       ...
# 1923457  0.787611  0.212389
# 1923492  0.613497  0.386503
# 1922934  0.667910  0.332090
# 1922884  0.637306  0.362694
# 1608101  0.733990  0.266010
#
# [152902 rows x 2 columns]
#  Done
# ['ATG']
#  Done
# Subset of codon columns for  M :
#             ATG
# Taxid
# 2161     22773
# 1204725  19558
# 2162     18228
# 2162     18418
# 2162     18470
# ...        ...
# 1923457     86
# 1923492     81
# 1922934    176
# 1922884    104
# 1608101    108
#
# [152902 rows x 1 columns]
#  Done
# Relative frequency of codon usage for M :
#           ATG
# Taxid
# 2161     1.0
# 1204725  1.0
# 2162     1.0
# 2162     1.0
# 2162     1.0
# ...      ...
# 1923457  1.0
# 1923492  1.0
# 1922934  1.0
# 1922884  1.0
# 1608101  1.0
#
# [152902 rows x 1 columns]
#  Done
# ['GAT', 'GAC']
#  Done
# Subset of codon columns for  D :
#             GAT    GAC
# Taxid
# 2161     37176  11948
# 1204725  28909  10659
# 2162     25204  11991
# 2162     25758  12132
# 2162     25863  12061
# ...        ...    ...
# 1923457    105     19
# 1923492    146     45
# 1922934    239     73
# 1922884    129     73
# 1608101    162     44
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for D :
#                GAT       GAC
# Taxid
# 2161     0.756779  0.243221
# 1204725  0.730616  0.269384
# 2162     0.677618  0.322382
# 2162     0.679810  0.320190
# 2162     0.681969  0.318031
# ...           ...       ...
# 1923457  0.846774  0.153226
# 1923492  0.764398  0.235602
# 1922934  0.766026  0.233974
# 1922884  0.638614  0.361386
# 1608101  0.786408  0.213592
#
# [152902 rows x 2 columns]
#  Done
# ['TTT', 'TTC']
#  Done
# Subset of codon columns for  F :
#             TTT    TTC
# Taxid
# 2161     27957  10549
# 1204725  15629  13487
# 2162     13417  13157
# 2162     13620  13539
# 2162     13914  13413
# ...        ...    ...
# 1923457     63     30
# 1923492     67     84
# 1922934    138     66
# 1922884    105     83
# 1608101     99     83
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for F :
#                TTT       TTC
# Taxid
# 2161     0.726043  0.273957
# 1204725  0.536784  0.463216
# 2162     0.504892  0.495108
# 2162     0.501491  0.498509
# 2162     0.509167  0.490833
# ...           ...       ...
# 1923457  0.677419  0.322581
# 1923492  0.443709  0.556291
# 1922934  0.676471  0.323529
# 1922884  0.558511  0.441489
# 1608101  0.543956  0.456044
#
# [152902 rows x 2 columns]
#  Done
# ['TGT', 'TGC']
#  Done
# Subset of codon columns for  C :
#            TGT   TGC
# Taxid
# 2161     6708  3754
# 1204725  5076  2835
# 2162     4726  2897
# 2162     4776  2883
# 2162     4807  2925
# ...       ...   ...
# 1923457    16     3
# 1923492    42    28
# 1922934    77    26
# 1922884    62    30
# 1608101    46    27
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for C :
#                TGT       TGC
# Taxid
# 2161     0.641178  0.358822
# 1204725  0.641638  0.358362
# 2162     0.619966  0.380034
# 2162     0.623580  0.376420
# 2162     0.621702  0.378298
# ...           ...       ...
# 1923457  0.842105  0.157895
# 1923492  0.600000  0.400000
# 1922934  0.747573  0.252427
# 1922884  0.673913  0.326087
# 1608101  0.630137  0.369863
#
# [152902 rows x 2 columns]
#  Done
# ['CCT', 'CCC', 'CCA', 'CCG']
#  Done
# Subset of codon columns for  P :
#             CCT    CCC    CCA   CCG
# Taxid
# 2161     13026   3728  12085  2395
# 1204725   8107   7569   9804  2150
# 2162      6422  10389   6749  3459
# 2162      6787  10426   7025  3428
# 2162      6589  10480   6854  3506
# ...        ...    ...    ...   ...
# 1923457     59      2     42     4
# 1923492     55     19     68     4
# 1922934     75     18     53    13
# 1922884     56     21     36     7
# 1608101     51     10     75     2
#
# [152902 rows x 4 columns]
#  Done
# Relative frequency of codon usage for P :
#                CCT       CCC       CCA       CCG
# Taxid
# 2161     0.417046  0.119357  0.386918  0.076679
# 1204725  0.293413  0.273941  0.354832  0.077814
# 2162     0.237685  0.384507  0.249787  0.128021
# 2162     0.245319  0.376852  0.253922  0.123907
# 2162     0.240220  0.382077  0.249882  0.127821
# ...           ...       ...       ...       ...
# 1923457  0.551402  0.018692  0.392523  0.037383
# 1923492  0.376712  0.130137  0.465753  0.027397
# 1922934  0.471698  0.113208  0.333333  0.081761
# 1922884  0.466667  0.175000  0.300000  0.058333
# 1608101  0.369565  0.072464  0.543478  0.014493
#
# [152902 rows x 4 columns]
#  Done
# ['CAA', 'CAG']
#  Done
# Subset of codon columns for  Q :
#             CAA    CAG
# Taxid
# 2161     10580  10578
# 1204725   7711  13183
# 2162      6911  14423
# 2162      7097  14407
# 2162      7011  14520
# ...        ...    ...
# 1923457     32     12
# 1923492     84     55
# 1922934    152     54
# 1922884     67     49
# 1608101     78     43
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for Q :
#                CAA       CAG
# Taxid
# 2161     0.500047  0.499953
# 1204725  0.369053  0.630947
# 2162     0.323943  0.676057
# 2162     0.330032  0.669968
# 2162     0.325624  0.674376
# ...           ...       ...
# 1923457  0.727273  0.272727
# 1923492  0.604317  0.395683
# 1922934  0.737864  0.262136
# 1922884  0.577586  0.422414
# 1608101  0.644628  0.355372
#
# [152902 rows x 2 columns]
#  Done
# ['TCT', 'TCC', 'TCA', 'TCG', 'AGT', 'AGC']
#  Done
# Subset of codon columns for  S :
#             TCT    TCC    TCA   TCG    AGT   AGC
# Taxid
# 2161     14106   5638  16499  2062  12272  7528
# 1204725   8260   9147  10452  1313  10277  4733
# 2162      6883  10773   7474  1805   9254  4739
# 2162      7055  10931   7631  1770   9484  4820
# 2162      7177  10949   7625  1854   9470  4747
# ...        ...    ...    ...   ...    ...   ...
# 1923457     72      6     74     6     30     4
# 1923492     55     16     59     3     57    26
# 1922934    119     54     96    14     65    29
# 1922884     84     45    106     8     57    29
# 1608101     97     30    128    14     70    31
#
# [152902 rows x 6 columns]
#  Done
# Relative frequency of codon usage for S :
#                TCT       TCC       TCA       TCG       AGT       AGC
# Taxid
# 2161     0.242767  0.097031  0.283951  0.035487  0.211204  0.129559
# 1204725  0.186954  0.207030  0.236567  0.029718  0.232606  0.107125
# 2162     0.168173  0.263218  0.182613  0.044102  0.226104  0.115789
# 2162     0.169221  0.262191  0.183037  0.042455  0.227483  0.115612
# 2162     0.171608  0.261800  0.182320  0.044331  0.226436  0.113505
# ...           ...       ...       ...       ...       ...       ...
# 1923457  0.375000  0.031250  0.385417  0.031250  0.156250  0.020833
# 1923492  0.254630  0.074074  0.273148  0.013889  0.263889  0.120370
# 1922934  0.315650  0.143236  0.254642  0.037135  0.172414  0.076923
# 1922884  0.255319  0.136778  0.322188  0.024316  0.173252  0.088146
# 1608101  0.262162  0.081081  0.345946  0.037838  0.189189  0.083784
#
# [152902 rows x 6 columns]
#  Done
# ['GAA', 'GAG']
#  Done
# Subset of codon columns for  E :
#             GAA    GAG
# Taxid
# 2161     52397  10553
# 1204725  39851  10982
# 2162     37772  11956
# 2162     38344  11992
# 2162     38317  12076
# ...        ...    ...
# 1923457    110     53
# 1923492     89     63
# 1922934    212     71
# 1922884    140    114
# 1608101    155    118
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for E :
#                GAA       GAG
# Taxid
# 2161     0.832359  0.167641
# 1204725  0.783959  0.216041
# 2162     0.759572  0.240428
# 2162     0.761761  0.238239
# 2162     0.760364  0.239636
# ...           ...       ...
# 1923457  0.674847  0.325153
# 1923492  0.585526  0.414474
# 1922934  0.749117  0.250883
# 1922884  0.551181  0.448819
# 1608101  0.567766  0.432234
#
# [152902 rows x 2 columns]
#  Done
# ['ACT', 'ACC', 'ACA', 'ACG']
#  Done
# Subset of codon columns for  T :
#             ACT    ACC    ACA   ACG
# Taxid
# 2161     17384   8097  19958  2495
# 1204725  12215  15205   9274  1299
# 2162     10323  17668   6496  1962
# 2162     10880  17928   6681  1982
# 2162     10613  17832   6624  2011
# ...        ...    ...    ...   ...
# 1923457     72      5     62     4
# 1923492     63     27    130     7
# 1922934     78     44     95     5
# 1922884     67     45     82     6
# 1608101     94     30     94     7
#
# [152902 rows x 4 columns]
#  Done
# Relative frequency of codon usage for T :
#                ACT       ACC       ACA       ACG
# Taxid
# 2161     0.362665  0.168920  0.416364  0.052051
# 1204725  0.321507  0.400205  0.244098  0.034191
# 2162     0.283218  0.484732  0.178222  0.053829
# 2162     0.290358  0.478450  0.178298  0.052894
# 2162     0.286219  0.480906  0.178641  0.054234
# ...           ...       ...       ...       ...
# 1923457  0.503497  0.034965  0.433566  0.027972
# 1923492  0.277533  0.118943  0.572687  0.030837
# 1922934  0.351351  0.198198  0.427928  0.022523
# 1922884  0.335000  0.225000  0.410000  0.030000
# 1608101  0.417778  0.133333  0.417778  0.031111
#
# [152902 rows x 4 columns]
#  Done
# ['GGT', 'GGC', 'GGA', 'GGG']
#  Done
# Subset of codon columns for  G :
#             GGT   GGC    GGA   GGG
# Taxid
# 2161     18614  8288  26302  8628
# 1204725  17285  5147  20669  6927
# 2162     15823  5784  18922  7763
# 2162     16092  5877  19426  7784
# 2162     16070  5842  19223  7858
# ...        ...   ...    ...   ...
# 1923457     76     7     30    11
# 1923492     71    24     54    27
# 1922934     51    29     77    22
# 1922884     53    31     41    23
# 1608101     70    21     58    20
#
# [152902 rows x 4 columns]
#  Done
# Relative frequency of codon usage for G :
#                GGT       GGC       GGA       GGG
# Taxid
# 2161     0.301042  0.134041  0.425378  0.139539
# 1204725  0.345507  0.102882  0.413149  0.138462
# 2162     0.327653  0.119771  0.391825  0.160751
# 2162     0.327213  0.119502  0.395006  0.158279
# 2162     0.328006  0.119242  0.392362  0.160390
# ...           ...       ...       ...       ...
# 1923457  0.612903  0.056452  0.241935  0.088710
# 1923492  0.403409  0.136364  0.306818  0.153409
# 1922934  0.284916  0.162011  0.430168  0.122905
# 1922884  0.358108  0.209459  0.277027  0.155405
# 1608101  0.414201  0.124260  0.343195  0.118343
#
# [152902 rows x 4 columns]
#  Done
# ['TGG']
#  Done
# Subset of codon columns for  W :
#            TGG
# Taxid
# 2161     7730
# 1204725  6203
# 2162     5836
# 2162     6063
# 2162     5948
# ...       ...
# 1923457    19
# 1923492    37
# 1922934    59
# 1922884    36
# 1608101    36
#
# [152902 rows x 1 columns]
#  Done
# Relative frequency of codon usage for W :
#           TGG
# Taxid
# 2161     1.0
# 1204725  1.0
# 2162     1.0
# 2162     1.0
# 2162     1.0
# ...      ...
# 1923457  1.0
# 1923492  1.0
# 1922934  1.0
# 1922884  1.0
# 1608101  1.0
#
# [152902 rows x 1 columns]
#  Done
# ['CAT', 'CAC']
#  Done
# Subset of codon columns for  H :
#             CAT   CAC
# Taxid
# 2161     10137  4643
# 1204725   7290  5607
# 2162      6278  6271
# 2162      6416  6341
# 2162      6394  6320
# ...        ...   ...
# 1923457     29    10
# 1923492     57    33
# 1922934    109    44
# 1922884     46    31
# 1608101     70    16
#
# [152902 rows x 2 columns]
#  Done
# Relative frequency of codon usage for H :
#                CAT       CAC
# Taxid
# 2161     0.685859  0.314141
# 1204725  0.565248  0.434752
# 2162     0.500279  0.499721
# 2162     0.502940  0.497060
# 2162     0.502910  0.497090
# ...           ...       ...
# 1923457  0.743590  0.256410
# 1923492  0.633333  0.366667
# 1922934  0.712418  0.287582
# 1922884  0.597403  0.402597
# 1608101  0.813953  0.186047
#
# [152902 rows x 2 columns]
#  Done
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-ae25be034ab7> in <module>
#      56     if verbose==True:
#      57         print("Relative frequency of codon usage for",AA,":\n", ratio_subdata,"\n Done")
# ---> 58     ratio_all=pd.concat([ratio_all,ratio_subdata])
#      59 #to do explicitely declares which columns has to be rounded
#      60 ratio_all=ratio_all.round(2)
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     333
#     334             # consolidate
# --> 335             obj._consolidate(inplace=True)
#     336             ndims.add(obj.ndim)
#     337
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    5268         inplace = validate_bool_kwarg(inplace, "inplace")
#    5269         if inplace:
# -> 5270             self._consolidate_inplace()
#    5271         else:
#    5272             f = lambda: self._data.consolidate()
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5250             self._data = self._data.consolidate()
#    5251
# -> 5252         self._protect_consolidate(f)
#    5253
#    5254     def _consolidate(self, inplace=False):
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5239         """
#    5240         blocks_before = len(self._data.blocks)
# -> 5241         result = f()
#    5242         if len(self._data.blocks) != blocks_before:
#    5243             self._clear_item_cache()
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/generic.py in f()
#    5248
#    5249         def f():
# -> 5250             self._data = self._data.consolidate()
#    5251
#    5252         self._protect_consolidate(f)
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     930         bm = self.__class__(self.blocks, self.axes)
#     931         bm._is_consolidated = False
# --> 932         bm._consolidate_inplace()
#     933         return bm
#     934
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     935     def _consolidate_inplace(self):
#     936         if not self.is_consolidated():
# --> 937             self.blocks = tuple(_consolidate(self.blocks))
#     938             self._is_consolidated = True
#     939             self._known_consolidated = True
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1911     for (_can_consolidate, dtype), group_blocks in grouper:
#    1912         merged_blocks = _merge_blocks(
# -> 1913             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1914         )
#    1915         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~/anaconda/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3321
#    3322         argsort = np.argsort(new_mgr_locs)
# -> 3323         new_values = new_values[argsort]
#    3324         new_mgr_locs = new_mgr_locs[argsort]
#    3325
#
# MemoryError:
